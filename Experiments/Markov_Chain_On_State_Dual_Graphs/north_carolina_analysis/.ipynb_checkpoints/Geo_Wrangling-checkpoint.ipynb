# %%
import geopandas as gpd
import pandas as pd
from gerrychain import Graph
import random
import networkx as nx
import numpy as np
#from gerrychain import Graph, Partition, Election
#from gerrychain.updaters import Tally, cut_edges


# vtd['vote_difference'] = vtd.EL16G_GV_R - vtd.EL16G_GV_D
# vtd.plot("vote_difference", legend = True, figsize = (20,20) )
# vtd_county.plot("EL12G_GV_R", legend = True, figsize = (10,10) )
#vtd_county = vtd.dissolve(by='County', aggfunc='sum')
#vtd_county.to_file("./data/NC_county_merged.json", driver="GeoJSON")

# %%
np.nan
# Out:
# nan

# %% [markdown]
# # Load and Process Data

# %%
vtd = gpd.read_file("./data/NC_VTD.shp").to_crs("EPSG:4269")
bg = gpd.read_file("./data/tl_2016_37_bg.shp").to_crs("EPSG:4269")
blocks = gpd.read_file("./data/blocks/tl_2016_37_tabblock10.shp").to_crs("EPSG:4269")

# %% [markdown]
# ## Join VTDs and Blocks

# %%
#joined_within = gpd.sjoin(blocks, vtd, how = 'left', predicate = 'within' )
#joined_within[["GEOID10", "VTD"]].groupby("GEOID10").agg('count').value_counts()

i = 0 # only change to 1 to experiment with block groups;
geo_table = [ blocks, bg][i]
geo_id = ["GEOID10", "GEOID"][i]

joined = gpd.sjoin(geo_table, vtd, how = 'left',  predicate = 'intersects' )
mapping = joined[[geo_id, "VTD"]]

# %% [markdown]
# ### Checking number of intersections:

# %%
display(joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts())
#counts = joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').rename(columns = {"VTD" : "NUM INTERSECTIONS"})
#m = joined.merge(counts, left_on = geo_id, right_index = True)
#m[m["NUM INTERSECTIONS"] <= 5].plot("NUM INTERSECTIONS", legend = True)
# Out:
# VTD
# 1      201318
# 2       73931
# 3       12086
# 4        1524
# 5         112
# 6          13
# 7           3
# dtype: int64

# %%
temp = joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
temp.iloc[0] / temp.sum()
# Out:
# 0.6966334125756521

# %% [markdown]
# ## Compute Area Ratios

# %%
# Intersect geos with VTDs, compute area ratios
geo_table_with_map = geo_table.merge(mapping)#.merge(vtd[["VTD", "geometry"]], suffixes = ('_block', '_vt') )
geo_with_vtd = geo_table_with_map.merge(vtd,
                                                      left_on = "VTD", right_on = "VTD",
                                                      suffixes = ('_geo', '_vtd'))

geo_geos = gpd.GeoSeries(geo_with_vtd.geometry_geo).to_crs("ESRI:103500")
geo_with_vtd['geo_intersect'] = geo_geos.intersection(gpd.GeoSeries(geo_with_vtd.geometry_vtd).to_crs("ESRI:103500"))
geo_with_vtd['geo_area'] = geo_geos.area
geo_with_vtd['intersect_area'] = gpd.GeoSeries(geo_with_vtd.geo_intersect).to_crs("ESRI:103500").area
geo_with_vtd['area_proportion'] =  geo_with_vtd['intersect_area'] / geo_with_vtd['geo_area']

# %%
#geo_with_vtd.head(5)

# %% [markdown]
# Confirming that the isspue of multiple intersections is mostly to do with small intersections. Would be good to understand it but not necessary.

# %%
geo_with_vtd[geo_with_vtd.area_proportion >= .2][[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
# Out:
# VTD
# 1      288215
# 2         772
# dtype: int64

# %%
temp = geo_with_vtd[geo_with_vtd.area_proportion >= .05][[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
temp.iloc[0] / temp.sum()
# Out:
# 0.9911829943907512

# %% [markdown]
# ## Adding in block level population

# %%
pops = pd.read_csv('./data/us2016_block_pops.csv')
pops['block_fips'] = pops.block_fips.astype("str")
vote_fields = ["EL16G_GV_R" , "EL16G_GV_D", "TOTPOP"]
fields = ['VTD', "GEOID10", 'geometry', 'area_proportion' ] +  vote_fields
geos_simple = geo_with_vtd.rename(columns = {"geometry_geo" : "geometry" })[fields]
geo_with_pop = geos_simple.merge(pops, left_on = geo_id, right_on = 'block_fips',)

# %%
# VTD level sums -- doing because the VTD tot pop is generally not equal to the sum of the block pops in it
# This indicates some data level issue , probably in addition to the non exact containment issue.
# Code to check:
# merged = geo_with_pop[["TOTPOP", "VTD"]].merge(geo_with_pop[["pop2016", "VTD"]].groupby("VTD").agg(sum).reset_index(), left_on = "VTD", right_on = "VTD")
# (merged.TOTPOP / merged.pop2016).sort_values().apply(lambda x : round(x,1) ).value_counts()
# But ignoring for now.
vtds_block_pops = geo_with_pop[["pop2016", "VTD"]].groupby("VTD").agg(sum)
vtds_block_pops.columns = ["pop2016_VTD_total"]
geo_with_pop = geo_with_pop.merge(vtds_block_pops, left_on = "VTD", right_index = True)
geo_with_pop['pop_proportion'] = geo_with_pop.pop2016 /  geo_with_pop.pop2016_VTD_total

# Filter out and set to zero for the ones where the intersectiokn is too small
# NB: I did not include this step the first itme running it; TODO -- rerun.

# %%
#geo_with_pop.area_proportion

# %%
#geo_with_pop['pop_proportion']  = geo_with_pop['pop_proportion']  * (geo_with_pop.area_proportion >= .2).astype(int)

# %%
vote_fields = ["EL16G_GV_R" , "EL16G_GV_D", "TOTPOP"]
for field in vote_fields:
    # Eventually replace with ecological inference or something
    geo_with_pop[field + "_block"] = geo_with_pop['pop_proportion'] * geo_with_pop[field]

# %%
#geo_with_pop = geo_with_pop
#gpd.GeoDataFrame(geo_with_pop).plot(field + "_block", legend = True, figsize = (10,10) )

# %% [markdown]
# ### Deduping : For each block, keep only the vote apportionment from the largest VTD.

# %%
gdf_dedupped = geo_with_pop.sort_values('area_proportion').drop_duplicates('GEOID10', keep='last')

# %%
gdf_subset.pop2016.sum() / geo_with_pop.pop2016.sum()
# Out:
# 0.6278388760008075

# %% [markdown]
# Dang that was a lot of dupes

# %%
# sanity checking
len(gdf_subset.GEOID10.unique()) / len(geo_with_pop.GEOID10.unique())
# Out:
# 1.0

# %% [markdown]
# ### Save  the work so far:

# %%
#geo_with_pop.to_csv("geo_with_pop.csv")
#.drop(columns = ["geometry_geo", "geometry_vtd", "geo_intersect"]

# %%
gdf_subset = gdf_dedupped[['VTD', "GEOID10", 'geometry', "TOTPOP", "pop2016", "pop_proportion", 'area_proportion' ] +  [ x + "_block" for x in vote_fields] ]
gdf_subset = gpd.GeoDataFrame(gdf_subset)

# %%
test = gpd.GeoDataFrame(gdf_subset, geometry="geometry", crs= "ESRI:103500")#.head(10)
test.to_file('./processed_data_outputs/blocks_with_votes.shp')
# Out:
# C:\Users\lnajt\AppData\Local\Temp\ipykernel_24728\2894013665.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   test.to_file('./processed_data_outputs/export.shp')

# %%
test_in = gpd.read_file('./processed_data_outputs/blocks_with_votes.shp')

# %% [markdown]
# # Building our own VTDs

# %% [markdown]
# SEe VTD properties notebook for info on properties of VTDs

# %% [markdown]
# ### Simple metamander strategy:

# %% [markdown]
# Attempt here is to try to force packing, by building VTDs in the democratic leaning areas that have many adjacencies. (Triangles) and that are square like away.
#
# Alternatively, can we make slightly larger VTDs in democratic areas?

# %% [markdown]
# One way to accomplish this; MCMC over

# %%
gdf_subset= gpd.GeoDataFrame(gdf_subset)

# %%
gdf_subset.plot("pop2016")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Metamanering VTDs by packing

# %% [markdown]
# ## Make Graph

# %%
gdf_subset['pos'] = gdf_subset.centroid
# Out:
# C:\Users\lnajt\AppData\Local\Temp\ipykernel_24728\522360522.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_subset['pos'] = gdf_subset.centroid

# %%
gdf_subset = gdf_subset.rename(columns = { "EL16G_GV_D_block" : "dem", "EL16G_GV_R_block" : "rep"})

# %%
gdf_subset['dem_prop'] = gdf_subset.dem / gdf_subset.TOTPOP_block
gdf_subset['rep_prop'] = gdf_subset.rep / gdf_subset.TOTPOP_block

# %% [markdown]
# ### Saving the gdf

# %%
gpd.GeoDataFrame(gdf_subset.drop(columns = ["pos"]), geometry = "geometry",
                 crs= "ESRI:103500").to_file('./processed_data_outputs/blocks_df.geojson', driver='GeoJSON')

# %% [markdown]
# ### Making and  saving the graph

# %%
blocks_graph = Graph.from_geodataframe(gdf_subset, ignore_errors=True)#
# Out:
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\adjacency.py:23: ShapelyDeprecationWarning: STRtree will be changed in 2.0.0 and will not be compatible with versions < 2.
#   tree = STRtree(geometries)
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:162: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   areas = df.geometry.area.to_dict()
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:272: UserWarning: NA values found in column dem_prop!
#   warnings.warn("NA values found in column {}!".format(column))
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:272: UserWarning: NA values found in column rep_prop!
#   warnings.warn("NA values found in column {}!".format(column))

# %%
blocks_graph.nodes[71710]
# Out:
# {'boundary_node': True,
#  'boundary_perim': 0.0006337105017212873,
#  'area': 1.1672849999990542e-07,
#  'VTD': '3716905',
#  'GEOID10': '371690703002006',
#  'geometry': <shapely.geometry.polygon.Polygon at 0x2abb2d6aec0>,
#  'TOTPOP': 1067,
#  'pop2016': 0,
#  'pop_proportion': 0.0,
#  'area_proportion': 0.23375256474219527,
#  'rep': 0.0,
#  'dem': 0.0,
#  'TOTPOP_block': 0.0,
#  'pos': <shapely.geometry.point.Point at 0x2ae9da2ae00>,
#  'dem_prop': nan,
#  'rep_prop': nan}

# %%
blocks_graph.to_json('./processed_data_outputs/blocks_graph.json', include_geometries_as_geojson=True)

# %%
blocks_graph_test = Graph.from_json('./processed_data_outputs/blocks_graph.json')

# %%
def agglomerate(graph, ag_field = "dem_prop", agg_field_threshold = .5,  pop_cap = 6000, steps = 1000000):
    # go through map, agglomerate VTDs that have similar EL16G_GV_D_block proportions, until pop_cap is reached
    # also allow merging of zero pop blocks with no condition.
    for i in range(steps):
        
        e = random.choice(list(graph.edges()))
        
        if  (graph.nodes[e[0]]['TOTPOP_block'] == 0 or
             graph.nodes[e[1]]['TOTPOP_block'] == 0 or
             (graph.nodes[e[0]][ag_field] >  agg_field_threshold and 
            graph.nodes[e[1]][ag_field] >  agg_field_threshold)):
            tot_pop = graph.nodes[e[0]]['TOTPOP_block'] + graph.nodes[e[1]]['TOTPOP_block']
            tot_dem = graph.nodes[e[0]]['dem']+ graph.nodes[e[1]]['dem']
            tot_rep = graph.nodes[e[0]]['rep'] + graph.nodes[e[1]]['rep']
            if tot_pop < pop_cap:
                print("contract")
                print(blocks_graph.nodes[e[0]])
                print(blocks_graph.nodes[e[1]])
                nx.contracted_nodes(graph, e[0], e[1], copy = False, self_loops = False)
                # according to documentation node named e[0] remains

                graph.nodes[e[0]]['TOTPOP_block'] = tot_pop
                graph.nodes[e[0]]['dem'] = tot_dem
                graph.nodes[e[0]]['rep'] = tot_rep
                if tot_pop !=0 :
                    
                    graph.nodes[e[0]]['dem_prop'] = tot_dem / tot_pop
                    graph.nodes[e[0]]['rep_prop'] = tot_rep / tot_pop
                else:
                    graph.nodes[e[0]]['dem_prop'] = np.nan
                    graph.nodes[e[0]]['rep_prop'] = np.nan

# %%
agglomerate(graph = blocks_graph_test, steps = 1000)
# Out:
# contract
# {'boundary_node': False, 'area': 1.0195485000047234e-06, 'VTD': '37181EH1', 'GEOID10': '371819609002038', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9FA8BDC0>, 'TOTPOP': 3184, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.999999975641096, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFBA4B50>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 2.9826500000761124e-08, 'VTD': '37181EH1', 'GEOID10': '371819609002039', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB985B7340>, 'TOTPOP': 3184, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC90A6B30>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.08981800000353e-06, 'VTD': '37047P02', 'GEOID10': '370479302001110', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACE02560>, 'TOTPOP': 1611, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC929F010>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.0003068699159999666, 'VTD': '37047P02', 'GEOID10': '370479302001141', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB97180AC0>, 'TOTPOP': 1611, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC92A78B0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 4.6162479999991864e-05, 'VTD': '3715502', 'GEOID10': '371559608012094', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8DA150C0>, 'TOTPOP': 5424, 'pop2016': 15, 'pop_proportion': 0.002057048820625343, 'area_proportion': 0.9999999560134771, 'rep': 1.0408667032364236, 'dem': 1.2260010970927044, 'TOTPOP_block': 11.15743280307186, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF9F5C90>, 'dem_prop': 0.10988200589970502, 'rep_prop': 0.09328908554572272}
# {'boundary_node': False, 'area': 3.2137249999943777e-06, 'VTD': '3715502', 'GEOID10': '371559608011033', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBC156860>, 'TOTPOP': 5424, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000004, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AECA0F79D0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 3.962814499994042e-06, 'VTD': '37187SK', 'GEOID10': '371879503001048', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB76531540>, 'TOTPOP': 1274, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999998, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC09D8EB0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.0011807264354999649, 'VTD': '37187SK', 'GEOID10': '371879503001044', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAAB61E40>, 'TOTPOP': 1274, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9156DD0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 2.7597579999851985e-06, 'VTD': '37135LI', 'GEOID10': '371350117001009', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB3826CB0>, 'TOTPOP': 2832, 'pop2016': 30, 'pop_proportion': 0.006172839506172839, 'area_proportion': 0.9999999160002818, 'rep': 1.765432098765432, 'dem': 8.895061728395062, 'TOTPOP_block': 17.48148148148148, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF82F3D0>, 'dem_prop': 0.5088276836158192, 'rep_prop': 0.10098870056497175}
# {'boundary_node': False, 'area': 4.0744716499985585e-05, 'VTD': '37135LI', 'GEOID10': '371350117002000', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AABE65FFA0>, 'TOTPOP': 2832, 'pop2016': 763, 'pop_proportion': 0.15699588477366255, 'area_proportion': 0.999999975092997, 'rep': 44.90082304526749, 'dem': 226.23106995884774, 'TOTPOP_block': 444.6123456790124, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFB98A90>, 'dem_prop': 0.5088276836158192, 'rep_prop': 0.10098870056497174}
# contract
# {'boundary_node': False, 'area': 9.80777999996264e-07, 'VTD': '3715938', 'GEOID10': '371590508001030', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAA7F1F90>, 'TOTPOP': 4217, 'pop2016': 5, 'pop_proportion': 0.0008819897689186806, 'area_proportion': 0.9999997661441304, 'rep': 0.5203739636620216, 'dem': 1.0336920091726935, 'TOTPOP_block': 3.719350855530076, 'pos': <shapely.geometry.point.Point object at 0x000002AE7388CD30>, 'dem_prop': 0.277922693858193, 'rep_prop': 0.13990988854636}
# {'boundary_node': False, 'area': 5.7169650001037e-07, 'VTD': '3715918', 'GEOID10': '371590508001035', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA9FC4820>, 'TOTPOP': 1663, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.999999768867529, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AE7388F850>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.0088124999987875e-06, 'VTD': '37135H', 'GEOID10': '371350110001043', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA7BEB310>, 'TOTPOP': 1271, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999994904906775, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AE73798670>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 3.4018810000051e-06, 'VTD': '37135H', 'GEOID10': '371350110001042', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8D5F4EB0>, 'TOTPOP': 1271, 'pop2016': 6, 'pop_proportion': 0.0020422055820285907, 'area_proportion': 0.9999999999999082, 'rep': 0.22668481960517356, 'dem': 1.4479237576582709, 'TOTPOP_block': 2.595643294758339, 'pos': <shapely.geometry.point.Point object at 0x000002AEC0152E90>, 'dem_prop': 0.5578284815106216, 'rep_prop': 0.08733280881195908}
# contract
# {'boundary_node': False, 'area': 1.4006034999965127e-06, 'VTD': '37045BSPGS', 'GEOID10': '370459515013002', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBCA6B100>, 'TOTPOP': 6475, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999999, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC08F7490>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 5.082541149998543e-05, 'VTD': '37045BSPGS', 'GEOID10': '370459515011002', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBDD77670>, 'TOTPOP': 6475, 'pop2016': 31, 'pop_proportion': 0.004085936470278107, 'area_proportion': 1.0000000000000004, 'rep': 7.75102148411757, 'dem': 3.4035850797416636, 'TOTPOP_block': 26.456438645050746, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9A45B70>, 'dem_prop': 0.12864864864864864, 'rep_prop': 0.292972972972973}
# contract
# {'boundary_node': False, 'area': 5.035785000011273e-06, 'VTD': '3712104', 'GEOID10': '371219503003032', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACF414E0>, 'TOTPOP': 8267, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999981, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC019F850>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 8.798949999955511e-07, 'VTD': '3712104', 'GEOID10': '371219503003034', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBB7012D0>, 'TOTPOP': 8267, 'pop2016': 9, 'pop_proportion': 0.000770152319014205, 'area_proportion': 1.0, 'rep': 2.295824062981345, 'dem': 0.8386958754064693, 'TOTPOP_block': 6.366849221290432, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8A9C2B0>, 'dem_prop': 0.131728559332285, 'rep_prop': 0.3605902987782751}
# contract
# {'boundary_node': False, 'area': 2.651160000023357e-07, 'VTD': '37099HAMMNT', 'GEOID10': '370999508001106', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9AFCD300>, 'TOTPOP': 2230, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999164662342, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF838FD0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.00017321623849998703, 'VTD': '37099RIV', 'GEOID10': '370999508001017', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB3B64430>, 'TOTPOP': 1359, 'pop2016': 3, 'pop_proportion': 0.00125, 'area_proportion': 0.9999999910533071, 'rep': 0.35375, 'dem': 0.28250000000000003, 'TOTPOP_block': 1.69875, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFE3EDD0>, 'dem_prop': 0.16629874908020606, 'rep_prop': 0.2082413539367182}
# contract
# {'boundary_node': False, 'area': 6.931824999998557e-07, 'VTD': '37193109', 'GEOID10': '371939609003046', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBDF670D0>, 'TOTPOP': 1253, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000002, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC96A46D0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 4.396137700000859e-05, 'VTD': '37193109', 'GEOID10': '371939609003039', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAEE234F0>, 'TOTPOP': 1253, 'pop2016': 5, 'pop_proportion': 0.002232142857142857, 'area_proportion': 1.0000000000000044, 'rep': 0.8080357142857142, 'dem': 0.3325892857142857, 'TOTPOP_block': 2.796875, 'pos': <shapely.geometry.point.Point object at 0x000002AECA4477F0>, 'dem_prop': 0.11891460494812449, 'rep_prop': 0.2889066241021548}
# contract
# {'boundary_node': False, 'area': 2.128740000007185e-06, 'VTD': '3702101.1', 'GEOID10': '370210001001013', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACCB31C0>, 'TOTPOP': 2310, 'pop2016': 128, 'pop_proportion': 0.04012539184952978, 'area_proportion': 0.9985831248490415, 'rep': 7.102194357366772, 'dem': 49.91598746081505, 'TOTPOP_block': 92.6896551724138, 'pos': <shapely.geometry.point.Point object at 0x000002AE7098BA30>, 'dem_prop': 0.5385281385281386, 'rep_prop': 0.07662337662337662}
# {'boundary_node': False, 'area': 2.3200825000000526e-06, 'VTD': '3702101.1', 'GEOID10': '370210001001019', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA611F700>, 'TOTPOP': 2310, 'pop2016': 48, 'pop_proportion': 0.015047021943573668, 'area_proportion': 0.9999999999999999, 'rep': 2.663322884012539, 'dem': 18.718495297805642, 'TOTPOP_block': 34.758620689655174, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8647910>, 'dem_prop': 0.5385281385281385, 'rep_prop': 0.07662337662337662}
# contract
# {'boundary_node': False, 'area': 0.00041808282149994984, 'VTD': '3704907', 'GEOID10': '370499603002036', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBB84D330>, 'TOTPOP': 3396, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999992336573, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC00C4D30>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 3.911361499983177e-06, 'VTD': '3704907', 'GEOID10': '370499603002041', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB845EA40>, 'TOTPOP': 3396, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000002, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9C7E0B0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 2.334190499993922e-06, 'VTD': '3704921', 'GEOID10': '370499610013052', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB88EAA2F0>, 'TOTPOP': 3093, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999992, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC02AEC50>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.00015956622099997668, 'VTD': '3704921', 'GEOID10': '370499610013049', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB86EDA680>, 'TOTPOP': 3093, 'pop2016': 99, 'pop_proportion': 0.024949596774193547, 'area_proportion': 0.9999999999999999, 'rep': 34.67993951612903, 'dem': 14.271169354838708, 'TOTPOP_block': 77.16910282258064, 'pos': <shapely.geometry.point.Point object at 0x000002AEC860AF50>, 'dem_prop': 0.18493372130617522, 'rep_prop': 0.4494018752020692}
# contract
# {'boundary_node': False, 'area': 1.8308842499983574e-05, 'VTD': '3703519', 'GEOID10': '370350111012013', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA5B4CCD0>, 'TOTPOP': 1779, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999986, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC01CC6D0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 2.6288830000152022e-06, 'VTD': '3703519', 'GEOID10': '370350111012001', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB769936A0>, 'TOTPOP': 1779, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8AF91B0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 4.739530000026358e-07, 'VTD': '371270031', 'GEOID10': '371270106022007', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA9DCF2E0>, 'TOTPOP': 1942, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999990331550029, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AE73709150>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 2.0466984000000524e-05, 'VTD': '371270040', 'GEOID10': '371270106022008', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB767B2E90>, 'TOTPOP': 8533, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999972803408, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC000E7D0>, 'dem_prop': nan, 'rep_prop': nan}

# %% [markdown]
# agglomerate(dem, 6000)
# agglomerate(rep, 2000)
# end up with bigger dem regions, VTD has caused packing
