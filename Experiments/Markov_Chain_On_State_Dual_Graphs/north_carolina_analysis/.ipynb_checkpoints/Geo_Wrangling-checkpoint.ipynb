# %%
import geopandas as gpd
import pandas as pd
from gerrychain import Graph
import random
import networkx as nx
import numpy as np
#from gerrychain import Graph, Partition, Election
#from gerrychain.updaters import Tally, cut_edges


# vtd['vote_difference'] = vtd.EL16G_GV_R - vtd.EL16G_GV_D
# vtd.plot("vote_difference", legend = True, figsize = (20,20) )
# vtd_county.plot("EL12G_GV_R", legend = True, figsize = (10,10) )
#vtd_county = vtd.dissolve(by='County', aggfunc='sum')
#vtd_county.to_file("./data/NC_county_merged.json", driver="GeoJSON")

# %%
np.nan
# Out:
# nan

# %% [markdown]
# # Load and Process Data

# %%
vtd = gpd.read_file("./data/NC_VTD.shp").to_crs("EPSG:4269")
bg = gpd.read_file("./data/tl_2016_37_bg.shp").to_crs("EPSG:4269")
blocks = gpd.read_file("./data/blocks/tl_2016_37_tabblock10.shp").to_crs("EPSG:4269")

# %% [markdown]
# ## Join VTDs and Blocks

# %%
#joined_within = gpd.sjoin(blocks, vtd, how = 'left', predicate = 'within' )
#joined_within[["GEOID10", "VTD"]].groupby("GEOID10").agg('count').value_counts()

i = 0 # only change to 1 to experiment with block groups;
geo_table = [ blocks, bg][i]
geo_id = ["GEOID10", "GEOID"][i]

joined = gpd.sjoin(geo_table, vtd, how = 'left',  predicate = 'intersects' )
mapping = joined[[geo_id, "VTD"]]

# %% [markdown]
# ### Checking number of intersections:

# %%
display(joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts())
#counts = joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').rename(columns = {"VTD" : "NUM INTERSECTIONS"})
#m = joined.merge(counts, left_on = geo_id, right_index = True)
#m[m["NUM INTERSECTIONS"] <= 5].plot("NUM INTERSECTIONS", legend = True)
# Out:
# VTD
# 1      201318
# 2       73931
# 3       12086
# 4        1524
# 5         112
# 6          13
# 7           3
# dtype: int64

# %%
temp = joined[[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
temp.iloc[0] / temp.sum()
# Out:
# 0.6966334125756521

# %% [markdown]
# ## Compute Area Ratios

# %%
# Intersect geos with VTDs, compute area ratios
geo_table_with_map = geo_table.merge(mapping)#.merge(vtd[["VTD", "geometry"]], suffixes = ('_block', '_vt') )
geo_with_vtd = geo_table_with_map.merge(vtd,
                                                      left_on = "VTD", right_on = "VTD",
                                                      suffixes = ('_geo', '_vtd'))

geo_geos = gpd.GeoSeries(geo_with_vtd.geometry_geo).to_crs("ESRI:103500")
geo_with_vtd['geo_intersect'] = geo_geos.intersection(gpd.GeoSeries(geo_with_vtd.geometry_vtd).to_crs("ESRI:103500"))
geo_with_vtd['geo_area'] = geo_geos.area
geo_with_vtd['intersect_area'] = gpd.GeoSeries(geo_with_vtd.geo_intersect).to_crs("ESRI:103500").area
geo_with_vtd['area_proportion'] =  geo_with_vtd['intersect_area'] / geo_with_vtd['geo_area']

# %%
#geo_with_vtd.head(5)

# %% [markdown]
# Confirming that the isspue of multiple intersections is mostly to do with small intersections. Would be good to understand it but not necessary.

# %%
geo_with_vtd[geo_with_vtd.area_proportion >= .2][[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
# Out:
# VTD
# 1      288215
# 2         772
# dtype: int64

# %%
temp = geo_with_vtd[geo_with_vtd.area_proportion >= .05][[geo_id, "VTD"]].groupby(geo_id).agg('count').value_counts()
temp.iloc[0] / temp.sum()
# Out:
# 0.9911829943907512

# %% [markdown]
# ## Adding in block level population

# %%
pops = pd.read_csv('./data/us2016_block_pops.csv')
pops['block_fips'] = pops.block_fips.astype("str")
vote_fields = ["EL16G_GV_R" , "EL16G_GV_D", "TOTPOP"]
fields = ['VTD', "GEOID10", 'geometry', 'area_proportion' ] +  vote_fields
geos_simple = geo_with_vtd.rename(columns = {"geometry_geo" : "geometry" })[fields]
geo_with_pop = geos_simple.merge(pops, left_on = geo_id, right_on = 'block_fips',)

# %%
# VTD level sums -- doing because the VTD tot pop is generally not equal to the sum of the block pops in it
# This indicates some data level issue , probably in addition to the non exact containment issue.
# Code to check:
# merged = geo_with_pop[["TOTPOP", "VTD"]].merge(geo_with_pop[["pop2016", "VTD"]].groupby("VTD").agg(sum).reset_index(), left_on = "VTD", right_on = "VTD")
# (merged.TOTPOP / merged.pop2016).sort_values().apply(lambda x : round(x,1) ).value_counts()
# But ignoring for now.
vtds_block_pops = geo_with_pop[["pop2016", "VTD"]].groupby("VTD").agg(sum)
vtds_block_pops.columns = ["pop2016_VTD_total"]
geo_with_pop = geo_with_pop.merge(vtds_block_pops, left_on = "VTD", right_index = True)
geo_with_pop['pop_proportion'] = geo_with_pop.pop2016 /  geo_with_pop.pop2016_VTD_total

# Filter out and set to zero for the ones where the intersectiokn is too small
# NB: I did not include this step the first itme running it; TODO -- rerun.

# %%
#geo_with_pop.area_proportion

# %%
#geo_with_pop['pop_proportion']  = geo_with_pop['pop_proportion']  * (geo_with_pop.area_proportion >= .2).astype(int)

# %%
vote_fields = ["EL16G_GV_R" , "EL16G_GV_D", "TOTPOP"]
for field in vote_fields:
    # Eventually replace with ecological inference or something
    geo_with_pop[field + "_block"] = geo_with_pop['pop_proportion'] * geo_with_pop[field]

# %%
#geo_with_pop = geo_with_pop
#gpd.GeoDataFrame(geo_with_pop).plot(field + "_block", legend = True, figsize = (10,10) )

# %% [markdown]
# ### Deduping : For each block, keep only the vote apportionment from the largest VTD.

# %%
gdf_dedupped = geo_with_pop.sort_values('area_proportion').drop_duplicates('GEOID10', keep='last')

# %%
gdf_subset.pop2016.sum() / geo_with_pop.pop2016.sum()
# Out:
# 0.6278388760008075

# %% [markdown]
# Dang that was a lot of dupes

# %%
# sanity checking
len(gdf_subset.GEOID10.unique()) / len(geo_with_pop.GEOID10.unique())
# Out:
# 1.0

# %% [markdown]
# ### Save  the work so far:

# %%
#geo_with_pop.to_csv("geo_with_pop.csv")
#.drop(columns = ["geometry_geo", "geometry_vtd", "geo_intersect"]

# %%
gdf_subset = gdf_dedupped[['VTD', "GEOID10", 'geometry', "TOTPOP", "pop2016", "pop_proportion", 'area_proportion' ] +  [ x + "_block" for x in vote_fields] ]
gdf_subset = gpd.GeoDataFrame(gdf_subset)

# %%
test = gpd.GeoDataFrame(gdf_subset, geometry="geometry", crs= "ESRI:103500")#.head(10)
test.to_file('./processed_data_outputs/blocks_with_votes.shp')
# Out:
# C:\Users\lnajt\AppData\Local\Temp\ipykernel_24728\2894013665.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   test.to_file('./processed_data_outputs/export.shp')

# %%
test_in = gpd.read_file('./processed_data_outputs/blocks_with_votes.shp')

# %% [markdown]
# # Building our own VTDs

# %% [markdown]
# SEe VTD properties notebook for info on properties of VTDs

# %% [markdown]
# ### Simple metamander strategy:

# %% [markdown]
# Attempt here is to try to force packing, by building VTDs in the democratic leaning areas that have many adjacencies. (Triangles) and that are square like away.
#
# Alternatively, can we make slightly larger VTDs in democratic areas?

# %% [markdown]
# One way to accomplish this; MCMC over

# %%
gdf_subset= gpd.GeoDataFrame(gdf_subset)

# %%
gdf_subset.plot("pop2016")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Metamanering VTDs by packing

# %% [markdown]
# ## Make Graph

# %%
gdf_subset['pos'] = gdf_subset.centroid
# Out:
# C:\Users\lnajt\AppData\Local\Temp\ipykernel_24728\522360522.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_subset['pos'] = gdf_subset.centroid

# %%
gdf_subset = gdf_subset.rename(columns = { "EL16G_GV_D_block" : "dem", "EL16G_GV_R_block" : "rep"})

# %%
gdf_subset['dem_prop'] = gdf_subset.dem / gdf_subset.TOTPOP_block
gdf_subset['rep_prop'] = gdf_subset.rep / gdf_subset.TOTPOP_block

# %% [markdown]
# ### Saving the gdf

# %%
gpd.GeoDataFrame(gdf_subset.drop(columns = ["pos"]), geometry = "geometry",
                 crs= "ESRI:103500").to_file('./processed_data_outputs/blocks_df.geojson', driver='GeoJSON')

# %% [markdown]
# ### Making and  saving the graph

# %%
blocks_graph = Graph.from_geodataframe(gdf_subset, ignore_errors=True)#
# Out:
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\adjacency.py:23: ShapelyDeprecationWarning: STRtree will be changed in 2.0.0 and will not be compatible with versions < 2.
#   tree = STRtree(geometries)
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:162: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   areas = df.geometry.area.to_dict()
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:272: UserWarning: NA values found in column dem_prop!
#   warnings.warn("NA values found in column {}!".format(column))
# C:\Users\lnajt\anaconda3\envs\gerry\lib\site-packages\gerrychain\graph\graph.py:272: UserWarning: NA values found in column rep_prop!
#   warnings.warn("NA values found in column {}!".format(column))

# %%
blocks_graph.nodes[71710]
# Out:
# {'boundary_node': True,
#  'boundary_perim': 0.0006337105017212873,
#  'area': 1.1672849999990542e-07,
#  'VTD': '3716905',
#  'GEOID10': '371690703002006',
#  'geometry': <shapely.geometry.polygon.Polygon at 0x2abb2d6aec0>,
#  'TOTPOP': 1067,
#  'pop2016': 0,
#  'pop_proportion': 0.0,
#  'area_proportion': 0.23375256474219527,
#  'rep': 0.0,
#  'dem': 0.0,
#  'TOTPOP_block': 0.0,
#  'pos': <shapely.geometry.point.Point at 0x2ae9da2ae00>,
#  'dem_prop': nan,
#  'rep_prop': nan}

# %%
blocks_graph.to_json('./processed_data_outputs/blocks_graph.json', include_geometries_as_geojson=True)

# %%
blocks_graph_test = Graph.from_json('./processed_data_outputs/blocks_graph.json')

# %%
def agglomerate(graph, ag_field = "dem_prop", agg_field_threshold = .5,  pop_cap = 6000, steps = 1000000):
    # go through map, agglomerate VTDs that have similar EL16G_GV_D_block proportions, until pop_cap is reached
    # also allow merging of zero pop blocks with no condition.
    for i in range(steps):
        
        e = random.choice(list(graph.edges()))
        
        if  (graph.nodes[e[0]]['TOTPOP_block'] == 0 or
             graph.nodes[e[1]]['TOTPOP_block'] == 0 or
             (graph.nodes[e[0]][ag_field] >  agg_field_threshold and 
            graph.nodes[e[1]][ag_field] >  agg_field_threshold)):
            tot_pop = graph.nodes[e[0]]['TOTPOP_block'] + graph.nodes[e[1]]['TOTPOP_block']
            tot_dem = graph.nodes[e[0]]['dem']+ graph.nodes[e[1]]['dem']
            tot_rep = graph.nodes[e[0]]['rep'] + graph.nodes[e[1]]['rep']
            if tot_pop < pop_cap:
                print("contract")
                print(blocks_graph.nodes[e[0]]['dem_prop', "rep_prop", "TOTPOP_block", "rep", "dem"])
                print(blocks_graph.nodes[e[1]]['dem_prop', "rep_prop", "TOTPOP_block", "rep", "dem"])
                nx.contracted_nodes(graph, e[0], e[1], copy = False, self_loops = False)
                # according to documentation node named e[0] remains

                graph.nodes[e[0]]['TOTPOP_block'] = tot_pop
                graph.nodes[e[0]]['dem'] = tot_dem
                graph.nodes[e[0]]['rep'] = tot_rep
                if tot_pop !=0 :
                    
                    graph.nodes[e[0]]['dem_prop'] = tot_dem / tot_pop
                    graph.nodes[e[0]]['rep_prop'] = tot_rep / tot_pop
                else:
                    graph.nodes[e[0]]['dem_prop'] = np.nan
                    graph.nodes[e[0]]['rep_prop'] = np.nan

# %%
agglomerate(graph = blocks_graph_test, steps = 1000)
# Out:
# contract
# {'boundary_node': False, 'area': 1.0195485000047234e-06, 'VTD': '37181EH1', 'GEOID10': '371819609002038', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9FA8BDC0>, 'TOTPOP': 3184, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.999999975641096, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFBA4B50>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 2.9826500000761124e-08, 'VTD': '37181EH1', 'GEOID10': '371819609002039', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB985B7340>, 'TOTPOP': 3184, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC90A6B30>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.08981800000353e-06, 'VTD': '37047P02', 'GEOID10': '370479302001110', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACE02560>, 'TOTPOP': 1611, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC929F010>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.0003068699159999666, 'VTD': '37047P02', 'GEOID10': '370479302001141', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB97180AC0>, 'TOTPOP': 1611, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC92A78B0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 4.6162479999991864e-05, 'VTD': '3715502', 'GEOID10': '371559608012094', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8DA150C0>, 'TOTPOP': 5424, 'pop2016': 15, 'pop_proportion': 0.002057048820625343, 'area_proportion': 0.9999999560134771, 'rep': 1.0408667032364236, 'dem': 1.2260010970927044, 'TOTPOP_block': 11.15743280307186, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF9F5C90>, 'dem_prop': 0.10988200589970502, 'rep_prop': 0.09328908554572272}
# {'boundary_node': False, 'area': 3.2137249999943777e-06, 'VTD': '3715502', 'GEOID10': '371559608011033', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB
 'pos': <shapely.geometry.point.Point object at 0x000002AEC9A45B70>, 'dem_prop': 0.12864864864864864, 'rep_prop': 0.292972972972973}
# contract
# {'boundary_node': False, 'area': 5.035785000011273e-06, 'VTD': '3712104', 'GEOID10': '371219503003032', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACF414E0>, 'TOTPOP': 8267, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999981, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC019F850>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 8.798949999955511e-07, 'VTD': '3712104', 'GEOID10': '371219503003034', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBB7012D0>, 'TOTPOP': 8267, 'pop2016': 9, 'pop_proportion': 0.000770152319014205, 'area_proportion': 1.0, 'rep': 2.295824062981345, 'dem': 0.8386958754064693, 'TOTPOP_block': 6.366849221290432, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8A9C2B0>, 'dem_prop': 0.131728559332285, 'rep_prop': 0.3605902987782751}
# contract
# {'boundary_node': False, 'area': 2.651160000023357e-07, 'VTD': '37099HAMMNT', 'GEOID10': '370999508001106', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9AFCD300>, 'TOTPOP': 2230, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999164662342, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF838FD0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 0.00017321623849998703, 'VTD': '37099RIV', 'GEOID10': '370999508001017', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB3B64430>, 'TOTPOP': 1359, 'pop2016': 3, 'pop_proportion': 0.00125, 'area_proportion': 0.9999999910533071, 'rep': 0.35375, 'dem': 0.28250000000000003, 'TOTPOP_block': 1.69875, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFE3EDD0>, 'dem_prop': 0.16629874908020606, 'rep_prop': 0.2082413539367182}
# contract
# {'boundary_node': False, 'area': 6.931824999998557e-07, 'VTD': '37193109', 'GEOID10': '371939609003046', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBDF670D0>, 'TOTPOP': 1253, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000002, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC96A46D0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 4.396137700000859e-05, 'VTD': '37193109', 'GEOID10': '371939609003039', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAEE234F0>, 'TOTPOP': 1253, 'pop2016': 5, 'pop_proportion': 0.002232142857142857, 'area_proportion': 1.0000000000000044, 'rep': 0.8080357142857142, 'dem': 0.3325892857142857, 'TOTPOP_block': 2.796875, 'pos': <shapely.geometry.point.Point object at 0x000002AECA4477F0>, 'dem_prop': 0.11891460494812449, 'rep_prop': 0.2889066241021548}
# contract
# {'boundary_node': False, 'area': 2.128740000007185e-06, 'VTD': '3702101.1', 'GEOID10': '370210001001013', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACCB31C0>, 'TOTPOP': 2310, 'pop2016': 128, 'pop_proportion': 0.04012539184952978, 'area_proportion': 0.9985831248490415, 'rep': 7.102194357366772, 'dem': 49.91598746081505, 'TOTPOP_block': 92.6896551724138, 'pos': <shapely.geometry.point.Point object at 0x000002AE7098BA30>, 'dem_prop': 0.5385281385281386, 'rep_prop': 0.07662337662337662}
# {'boundary_node': False, 'area': 2.3200825000000526e-06, 'VTD': '3702101.1', 'GEOID10': '370210001001019', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA611F700>, 'TOTPOP': 2310, 'pop2016': 48, 'pop_proportion': 0.015047021943573668, 'area_proportion': 0.9999999999999999, 'rep': 2.663322884012539, 'dem': 18.718495297805642, 'TOTPOP_block': 34.758620689655174, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8647910>, 'dem_prop': 0.5385281385281385, 'rep_prop': 0.07662337662337662}
# contract
# {'boundary_node': False, 'area': 0.00041808282149994984, 'VTD': '3704907', 'GEOID10': '370499603002036', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBB84D330>, 'TOTPOP': 3396, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999992336573, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC00C4D30>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 3.911361499983177e-06, 'VTD': '3704907', 'GEOID10': '370499603002041', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB
 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9923A350>, 'TOTPOP': 3747, 'pop2016': 116, 'pop_proportion': 0.026721953466943102, 'area_proportion': 0.9999999999999984, 'rep': 24.878138677724028, 'dem': 31.53190509099286, 'TOTPOP_block': 100.12715964063581, 'pos': <shapely.geometry.point.Point object at 0x000002AEC01BFB50>, 'dem_prop': 0.31491860154790496, 'rep_prop': 0.24846543901788096}
# {'boundary_node': False, 'area': 6.6767549999948666e-06, 'VTD': '37149TR123', 'GEOID10': '371499203011061', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB88FFF670>, 'TOTPOP': 3747, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999998, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC07CC430>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 4.827784999895874e-07, 'VTD': '37031BFT1', 'GEOID10': '370319703031058', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB78F744C0>, 'TOTPOP': 1749, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999998, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8592710>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 1.0369730000058508e-06, 'VTD': '37031BFT1', 'GEOID10': '370319703031059', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA4004850>, 'TOTPOP': 1749, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8ED18D0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 5.266885000026907e-07, 'VTD': '37181MIDD', 'GEOID10': '371819601003019', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAAB63C10>, 'TOTPOP': 3712, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999998, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC07A6B90>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 9.017160000052237e-07, 'VTD': '37181MIDD', 'GEOID10': '371819601003038', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8EB6F910>, 'TOTPOP': 3712, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC90BD390>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.4347920000044086e-06, 'VTD': '3715525', 'GEOID10': '371559606003005', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8D39FFA0>, 'TOTPOP': 3860, 'pop2016': 2, 'pop_proportion': 0.0003189284005740711, 'area_proportion': 0.9999999128684314, 'rep': 0.147982777866369, 'dem': 0.10428958698772126, 'TOTPOP_block': 1.2310636262159145, 'pos': <shapely.geometry.point.Point object at 0x000002AEBF816470>, 'dem_prop': 0.08471502590673576, 'rep_prop': 0.12020725388601036}
# {'boundary_node': False, 'area': 1.1048241500013958e-05, 'VTD': '3715525', 'GEOID10': '371559606003004', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABC02A1E70>, 'TOTPOP': 3860, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000004, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC99F7310>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 0.0003305489695000204, 'VTD': '37081JEF3', 'GEOID10': '370810128032041', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB2878B0D0>, 'TOTPOP': 4433, 'pop2016': 428, 'pop_proportion': 0.061186561829878486, 'area_proportion': 0.9999999979599602, 'rep': 27.962258756254467, 'dem': 141.6468906361687, 'TOTPOP_block': 271.24002859185134, 'pos': <shapely.geometry.point.Point object at 0x000002AEC004D930>, 'dem_prop': 0.5222197157681029, 'rep_prop': 0.1030904579291676}
# {'boundary_node': False, 'area': 1.423583000002275e-06, 'VTD': '37081JEF3', 'GEOID10': '370810128032050', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAA975F60>, 'TOTPOP': 4433, 'pop2016': 5, 'pop_proportion': 0.0007147962830593281, 'area_proportion': 0.9999999999999999, 'rep': 0.32666190135811296, 'dem': 1.6547533952823446, 'TOTPOP_block': 3.1686919228020014, 'pos': <shapely.geometry.point.Point object at 0x000002AEC88E9F90>, 'dem_prop': 0.5222197157681029, 'rep_prop': 0.10309045792916761}
# contract
# {'boundary_node': False, 'area': 7.853229999986643e-07, 'VTD': '37119212', 'GEOID10': '371190055201031', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB2E0A4D0>, 'TOTPOP': 15216, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999996, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC0570E50>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 9.545049999970748e-07, 'VTD': '37119212', 'GEOID10': '371190055201017', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB84805900>, 'TOTPOP': 15216, 'pop2016': 17, 'pop_proportion': 0.0007321274763135229, 'area_proportion': 1.0, 'rep': 0.9686046511627907, 'dem': 3.7799741602067187, 'TOTPOP_block': 11.140051679586565, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9567FD0>, 'dem_prop': 0.33931388012618297, 'rep_prop': 0.08694794952681387}
# contract
# {'boundary_node': False, 'area': 2.161866000011943e-06, 'VTD': '3717103', 'GEOID10': '371719310022022', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8724A110>, 'TOTPOP': 4070, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999999999999959, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC0174BB0>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 1.1862725000017072e-06, 'VTD': '3717103', 'GEOID10': '371719310022023', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8990A2F0>, 'TOTPOP': 4070, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000002, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9765030>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 0.00029816034849998257, 'VTD': '37197SBCK', 'GEOID10': '371970504005033', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB181D7580>, 'TOTPOP': 1368, 'pop2016': 18, 'pop_proportion': 0.006859756097560976, 'area_proportion': 0.9999999999998278, 'rep': 3.09375, 'dem': 1.0221036585365855, 'TOTPOP_block': 9.384146341463415, 'pos': <shapely.geometry.point.Point object at 0x000002AEC0150D30>, 'dem_prop': 0.10891812865497076, 'rep_prop': 0.3296783625730994}
# ...
# contract
# {'boundary_node': False, 'area': 2.9151404999980707e-06, 'VTD': '3719119', 'GEOID10': '371910005001048', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB76A37610>, 'TOTPOP': 2575, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 0.9999998369064348, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AE73934A30>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 6.0569380999980563e-05, 'VTD': '3719117', 'GEOID10': '371910005001047', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB8B760430>, 'TOTPOP': 3038, 'pop2016': 3, 'pop_proportion': 0.0006339814032121725, 'area_proportion': 0.9999999815649256, 'rep': 0.04881656804733728, 'dem': 0.4361792054099747, 'TOTPOP_block': 1.9260355029585798, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFC718D0>, 'dem_prop': 0.22646477946017118, 'rep_prop': 0.02534562211981567}
# contract
# {'boundary_node': False, 'area': 1.4274115000036516e-06, 'VTD': '37081G74', 'GEOID10': '370810111022009', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB98AB2FE0>, 'TOTPOP': 2602, 'pop2016': 28, 'pop_proportion': 0.00834326579261025, 'area_proportion': 1.0, 'rep': 0.4088200238379023, 'dem': 12.62336114421931, 'TOTPOP_block': 21.709177592371873, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8B742B0>, 'dem_prop': 0.5814757878554958, 'rep_prop': 0.018831667947732514}
# {'boundary_node': False, 'area': 2.05525399999483e-06, 'VTD': '37081G74', 'GEOID10': '370810111021010', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABA3B89480>, 'TOTPOP': 2602, 'pop2016': 44, 'pop_proportion': 0.013110846245530394, 'area_proportion': 1.0, 'rep': 0.6424314660309893, 'dem': 19.836710369487484, 'TOTPOP_block': 34.11442193087009, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8B74430>, 'dem_prop': 0.5814757878554957, 'rep_prop': 0.018831667947732514}
# contract
# {'boundary_node': False, 'area': 6.15318999992453e-07, 'VTD': '3718301-20', 'GEOID10': '371830507003009', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAAABC460>, 'TOTPOP': 3583, 'pop2016': 22, 'pop_proportion': 0.0025992438563327033, 'area_proportion': 1.0, 'rep': 0.5354442344045369, 'dem': 4.743620037807183, 'TOTPOP_block': 9.313090737240076, 'pos': <shapely.geometry.point.Point object at 0x000002AEC871E050>, 'dem_prop': 0.5093497069494837, 'rep_prop': 0.05749372034607871}
# {'boundary_node': False, 'area': 2.037417300001746e-05, 'VTD': '3718301-20', 'GEOID10': '371830507003006', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB5CA65F0>, 'TOTPOP': 3583, 'pop2016': 346, 'pop_proportion': 0.040879017013232516, 'area_proportion': 1.0000000000000007, 'rep': 8.421077504725899, 'dem': 74.60420604914934, 'TOTPOP_block': 146.4695179584121, 'pos': <shapely.geometry.point.Point object at 0x000002AECA264610>, 'dem_prop': 0.5093497069494837, 'rep_prop': 0.05749372034607871}
# contract
# {'boundary_node': False, 'area': 1.203715999988454e-06, 'VTD': '37107PH2', 'GEOID10': '371070112001052', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBFD69E70>, 'TOTPOP': 1970, 'pop2016': 13, 'pop_proportion': 0.005396430053964301, 'area_proportion': 1.0, 'rep': 3.496886674968867, 'dem': 0.7555002075550021, 'TOTPOP_block': 10.630967206309672, 'pos': <shapely.geometry.point.Point object at 0x000002AEC90E8550>, 'dem_prop': 0.07106598984771574, 'rep_prop': 0.3289340101522843}
# {'boundary_node': False, 'area': 2.424006500004859e-06, 'VTD': '37107PH2', 'GEOID10': '371070112001053', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBC72E0E0>, 'TOTPOP': 1970, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC90E8A90>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.3338859999937032e-06, 'VTD': '37081G01', 'GEOID10': '370810109001015', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9EFE5270>, 'TOTPOP': 1403, 'pop2016': 5, 'pop_proportion': 0.0020859407592824365, 'area_proportion': 0.9999997253307014, 'rep': 0.16270337922403005, 'dem': 1.691697955778056, 'TOTPOP_block': 2.9265748852732583, 'pos': <shapely.geometry.point.Point object at 0x000002AE7384D870>, 'dem_prop': 0.5780470420527442, 'rep_prop': 0.05559515324305061}
# {'boundary_node': False, 'area': 1.2101724999939154e-06, 'VTD': '37081G67', 'GEOID10': '370810110002002', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9EC22AA0>, 'TOTPOP': 1764, 'pop2016': 18, 'pop_proportion': 0.004984768762115757, 'area_proportion': 0.9999997433138803, 'rep': 0.14455829410135695, 'dem': 4.845195236776516, 'TOTPOP_block': 8.793132096372196, 'pos': <shapely.geometry.point.Point object at 0x000002AE73865E70>, 'dem_prop': 0.5510204081632654, 'rep_prop': 0.016439909297052153}
# contract
# {'boundary_node': False, 'area': 0.00018281838800001695, 'VTD': '37083RINGW', 'GEOID10': '370839308004069', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABACEA1330>, 'TOTPOP': 1818, 'pop2016': 27, 'pop_proportion': 0.010625737898465172, 'area_proportion': 0.999999999999999, 'rep': 1.2538370720188903, 'dem': 9.02125147579693, 'TOTPOP_block': 19.317591499409684, 'pos': <shapely.geometry.point.Point object at 0x000002AEC0247730>, 'dem_prop': 0.46699669966996693, 'rep_prop': 0.0649064906490649}
# {'boundary_node': False, 'area': 6.123524449998652e-05, 'VTD': '37083RINGW', 'GEOID10': '370839308004073', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABB344D480>, 'TOTPOP': 1818, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000004, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AECA16B010>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 1.765562000006901e-06, 'VTD': '37131RICH-S', 'GEOID10': '371319202001015', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABAF297E50>, 'TOTPOP': 2008, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC8EC5270>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 6.743879499997163e-06, 'VTD': '37131RICH-S', 'GEOID10': '371319202001007', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002ABBBCD1ED0>, 'TOTPOP': 2008, 'pop2016': 37, 'pop_proportion': 0.013962264150943397, 'area_proportion': 1.0000000000000002, 'rep': 2.9320754716981132, 'dem': 10.27622641509434, 'TOTPOP_block': 28.03622641509434, 'pos': <shapely.geometry.point.Point object at 0x000002AEC
 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000002, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC9C199F0>, 'dem_prop': nan, 'rep_prop': nan}
# contract
# {'boundary_node': False, 'area': 3.1833755000021074e-06, 'VTD': '3702147.1', 'GEOID10': '370210024013021', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9B4CFD30>, 'TOTPOP': 5810, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AEC908DB70>, 'dem_prop': nan, 'rep_prop': nan}
# {'boundary_node': False, 'area': 6.977897499992928e-06, 'VTD': '3702147.1', 'GEOID10': '370210024013007', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB9CB7DDB0>, 'TOTPOP': 5810, 'pop2016': 1, 'pop_proportion': 0.00010950503723171266, 'area_proportion': 1.0000000000000007, 'rep': 0.18933420937363118, 'dem': 0.11925098554533509, 'TOTPOP_block': 0.6362242663162505, 'pos': <shapely.geometry.point.Point object at 0x000002AECA2A2170>, 'dem_prop': 0.1874354561101549, 'rep_prop': 0.29759036144578316}
# contract
# {'boundary_node': False, 'area': 3.385236500001563e-05, 'VTD': '3700110S', 'GEOID10': '370010212053058', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB89470AC0>, 'TOTPOP': 8086, 'pop2016': 5, 'pop_proportion': 0.0004674644727000748, 'area_proportion': 0.9999999879586895, 'rep': 1.0158002991772626, 'dem': 1.2214846671652955, 'TOTPOP_block': 3.7799177262528048, 'pos': <shapely.geometry.point.Point object at 0x000002AEBFD91570>, 'dem_prop': 0.32315112540192925, 'rep_prop': 0.2687360870640613}
# {'boundary_node': False, 'area': 4.148483499999729e-06, 'VTD': '3700110S', 'GEOID10': '370010212053060', 'geometry': <shapely.geometry.polygon.Polygon object at 0x000002AB76BEBEB0>, 'TOTPOP': 8086, 'pop2016': 0, 'pop_proportion': 0.0, 'area_proportion': 1.0000000000000004, 'rep': 0.0, 'dem': 0.0, 'TOTPOP_block': 0.0, 'pos': <shapely.geometry.point.Point object at 0x000002AECA0FFCD0>, 'dem_prop': nan, 'rep_prop': nan}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [207], line 1
# ----> 1 agglomerate(graph = blocks_graph_test, steps = 1000)
#
# Cell In [206], line 6, in agglomerate(graph, ag_field, agg_field_threshold, pop_cap, steps)
#       1 def agglomerate(graph, ag_field = "dem_prop", agg_field_threshold = .5,  pop_cap = 6000, steps = 1000000):
#       2     # go through map, agglomerate VTDs that have similar EL16G_GV_D_block proportions, until pop_cap is reached
#       3     # also allow merging of zero pop blocks with no condition.
#       4     for i in range(steps):
# ----> 6         e = random.choice(list(graph.edges()))
#       8         if  (graph.nodes[e[0]]['TOTPOP_block'] == 0 or
#       9              graph.nodes[e[1]]['TOTPOP_block'] == 0 or
#      10              (graph.nodes[e[0]][ag_field] >  agg_field_threshold and
#      11             graph.nodes[e[1]][ag_field] >  agg_field_threshold)):
#      12             tot_pop = graph.nodes[e[0]]['TOTPOP_block'] + graph.nodes[e[1]]['TOTPOP_block']
#
# File ~\anaconda3\envs\gerry\lib\site-packages\networkx\classes\reportviews.py:1271, in EdgeView.__iter__(self)
#    1269 for n, nbrs in self._nodes_nbrs():
#    1270     for nbr in list(nbrs):
# -> 1271         if nbr not in seen:
#    1272             yield (n, nbr)
#    1273     seen[n] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# agglomerate(dem, 6000)
# agglomerate(rep, 2000)
# end up with bigger dem regions, VTD has caused packing
